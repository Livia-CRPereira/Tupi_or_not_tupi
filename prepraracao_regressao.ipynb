# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from matplotlib.ticker import FuncFormatter
from google.colab import drive
import os

drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/projeto_icd/data_base/dados_regressao_construcao.csv')
# Out:
# Mounted at /content/drive

# %%
tamanho_amostra = 5000
caminho_arquivo = '/content/drive/MyDrive/projeto_icd/data_base/amostra_5000_regressao.csv'


df_amostra = df.sample(n=tamanho_amostra, random_state=42)

df_amostra.to_csv(caminho_arquivo, index=False)

print(f"✅ Amostra de {tamanho_amostra} linhas criada e salva em:")
print(caminho_arquivo)
# Out:
# ✅ Amostra de 5000 linhas criada e salva em:
# /content/drive/MyDrive/projeto_icd/data_base/amostra_5000_regressao.csv

# %%
df_amostra.columns
# Out:
# Index(['nu_altura', 'idade_meses_atend', 'tp_sexo', 'tipo_aleitamento',
#        'nu_peso', 'dsei_gestao', 'sg_uf', 'ds_cbo_familia'],
#       dtype='object')

# %%
df_amostra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 558224 to 506723
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nu_altura          5000 non-null   float64
#  1   idade_meses_atend  5000 non-null   float64
#  2   tp_sexo            5000 non-null   object
#  3   tipo_aleitamento   5000 non-null   object
#  4   nu_peso            5000 non-null   float64
#  5   dsei_gestao        5000 non-null   object
#  6   sg_uf              5000 non-null   object
#  7   ds_cbo_familia     5000 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 351.6+ KB

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# Montar o Drive (se você ainda não o fez na sessão atual)
try:
    drive.mount('/content/drive')
except:
    pass # Assume-se que já está montado ou não é Colab/Drive

# --- VARIÁVEIS DE CONFIGURAÇÃO ---
tamanho_teste = 500
caminho_teste = '/content/drive/MyDrive/projeto_icd/data_base/amostra_500_teste_predicao.csv'


indices_treino = df_amostra.index
df_restante = df.drop(indices_treino)

# 2. Verificar se há dados suficientes para a amostra de teste
if len(df_restante) < tamanho_teste:
    print(f"❌ Erro: Restam apenas {len(df_restante)} linhas. Não é possível criar a amostra de teste de {tamanho_teste} linhas.")
else:
    # 3. Criar a Amostra de Teste (500 linhas)
    # A amostragem é feita a partir do DataFrame que excluiu os dados de treino.
    # Usamos um novo seed para a amostragem de teste.
    df_teste = df_restante.sample(n=tamanho_teste, random_state=123)

    # 4. Salvar a amostra de teste no Google Drive
    df_teste.to_csv(caminho_teste, index=False)

    print(f"✅ Amostra de Teste de {tamanho_teste} linhas criada e salva com sucesso.")
    print(f"Caminho: {caminho_teste}")

    # Manter df_teste na memória para a próxima etapa
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Amostra de Teste de 500 linhas criada e salva com sucesso.
# Caminho: /content/drive/MyDrive/projeto_icd/data_base/amostra_500_teste_predicao.csv
